# %% [markdown]
# # AI - Vacuum agent, empty program
#
# Created (R. Basili, Nov. 2020)
# Modified (C.D. Hromei, Oct 2024)

# %% [markdown]
# ## Exercises
#
# 1. Fill the program of the `Agent` in order to reproduce the behaviour of random moves.
# 2. Fill the program of the `Agent` in order to search for the closest dirty room, go there and `Suck`.
#     **Hint**: you should modify the `Perception` method of the Environment as well to make it Completely Observable.
# 3. Modify the `Environment` locations into a 2x2 matrix instead of a row.
# 4. Modify the `Execute action` method of the Environment in order to implement a probabilistic failure of the action chosen by the Agent. In that case, the action should fail and nothing happens!

# %%
from tkinter import *
import random
from agents import *

collections.Callable = collections.abc.Callable

"""
loc_A loc_B

loc_C loc_D

"""
locs = ((0, 0), (1, 0), (0, 1), (1, 1))
pos = ((100, 100), (400, 100), (100, 300), (400, 300))
loc_A, loc_B, loc_C, loc_D = locs  # The three locations for the Vacuum world
pos_A, pos_B, pos_C, pos_D = pos  # The three locations for the Vacuum world

NBUTTONS = 4

class Gui(Environment):

    """This GUI environment has three locations, A, B and C. Each can be Dirty
    or Clean. The agent perceives its location and the location's
    status."""

    def __init__(self, root, height=400, width=520):
        super().__init__()
        self.status = {loc_A: 'Dirty',
                       loc_B: 'Dirty', 
                       loc_C: 'Clean',
                       loc_D: 'Clean'}
        self.root = root
        self.height = height
        self.width = width
        self.canvas = None
        self.buttons = []
        self.create_canvas()
        self.create_buttons()

    def thing_classes(self):
        """The list of things which can be used in the environment."""
        return [Wall, Dirt, ReflexVacuumAgent, RandomVacuumAgent,
                TableDrivenVacuumAgent, ModelBasedVacuumAgent]

    def percept(self, agent):
        """Returns the agent's location, and the location status (Dirty/Clean)."""
        print('Perceived Location=', agent.location,' - Perceived StatusAtLoc=',  self.status[agent.location])
        # Per farlo totalmente osservabile, bisogna ritornare le posizioni di tutte le location, con il loro status
        
        #return (agent.location, self.status[loc_A], self.status[loc_B], self.status[loc_C])
        
        return (agent.location, self.status) #(agent.location, self.status[agent.location])

    def execute_action(self, agent, action):
        """Change the location status (Dirty/Clean); track performance.
        Score 10 for each dirt cleaned; -1 for each move."""
        print('Executing action: ', action)
        if action == 'Right':
            if agent.location == loc_A:
                agent.location=loc_B
            elif agent.location == loc_C:
                agent.location = loc_D
        elif action == 'Left':
            if agent.location == loc_B:
                agent.location = loc_A
            elif agent.location == loc_D:
                agent.location = loc_C
        elif action == 'Down':
            if agent.location == loc_A:
                agent.location=loc_C
            elif agent.location == loc_B:
                agent.location = loc_D
        elif action == 'Up':
            if agent.location == loc_C:
                agent.location=loc_A
            elif agent.location == loc_D:
                agent.location = loc_B
            agent.performance -= 1
        elif action == 'Suck':
            if self.status[agent.location] == 'Dirty':
                self.buttons[locs.index(agent.location)].config(bg='white', activebackground='light grey')
                
                # if agent.location == loc_A:
                #     self.buttons[0].config(bg='white', activebackground='light grey')
                # elif agent.location == loc_B:
                #     self.buttons[1].config(bg='white', activebackground='light grey')
                # else:
                #     self.buttons[2].config(bg='white', activebackground='light grey')
                agent.performance += 10
            self.status[agent.location] = 'Clean'

    def default_location(self, thing):
        """Agents start in either location at random."""
        return random.choice(locs)

    ###################################################################################################
    #                        INTERFACE METHODS NOT USEFULL FOR THE AGENT/ENVIRONMENT
    ###################################################################################################
    def create_canvas(self):
        """Creates Canvas element in the GUI."""
        self.canvas = Canvas(
            self.root,
            width=self.width,
            height=self.height,
            background='powder blue')
        self.canvas.pack(side='bottom')

    def create_buttons(self):
        """Creates the buttons required in the GUI."""
        text = "ABCD"
        
        for i in range(NBUTTONS):
            x, y = pos[i]
            # Create and append the button
            # A B
            # C D
            b = Button(self.root, height=4, width=12, padx=2, pady=2, bg='white', text=text[i])
            b.config(command=lambda btn=b: self.dirt_switch(btn))
            self.buttons.append(b)
            _ = self.canvas.create_window(x, y, anchor=N, window=b)
            
    def dirt_switch(self, button):
        """Gives user the option to put dirt in any tile."""
        bg_color = button['bg']
        if bg_color == 'saddle brown':
            button.config(bg='white', activebackground='light grey')
        elif bg_color == 'white':
            button.config(bg='saddle brown', activebackground='light goldenrod')

    def read_env(self):
        """Reads the current state of the GUI."""
        
        for i, btn in enumerate(self.buttons):
            
            if btn['bg'] == 'white':
                self.status[locs[i]] = 'Clean'
            else:
                self.status[locs[i]] = 'Dirty'
                

    def update_env(self, agent):
        """Updates the GUI according to the agent's action."""
        self.read_env()
        print(self.status)
        before_step = agent.location
        self.step()   #execute_actions
        print('Current Environment Status: ', self.status)
        print('Current Agent Location: ',agent.location)
        move_agent(self, agent, before_step)

###################################################################################################
#                                           THE AGENT
###################################################################################################

def ReflexVacuumAgent():
    """A reflex agent for the two-state vacuum environment. [Figure 2.8]
    >>> agent = ReflexVacuumAgent()
    >>> environment = TrivialVacuumEnvironment()
    >>> environment.add_thing(agent)
    >>> environment.run()
    >>> environment.status == {(1,0):'Clean' , (0,0) : 'Clean'}
    True
    """
    
    def program(percept):
        
        location, status = percept
        
        print('Perceived Status: ', percept)
        
        action = ""
        
        if status[location] == 'Dirty':
            return 'Suck'
        
        if "Dirty" not in list(status.values()):
            if location == loc_A:
                return random.choice(["Right", "Down"])
            elif location == loc_B:
                return random.choice(["Left", "Down"])
            if location == loc_C:
                return random.choice(["Right", "Up"])
            elif location == loc_D:
                return random.choice(["Left", "Up"])
        
        vals = list(status.values())
        
        for _, stat in status.items():
            if location == loc_A: 
                if 'Dirty' == vals[locs.index(loc_B)]:
                    return "Right"
                elif 'Dirty' == vals[locs.index(loc_C)]:
                    return "Down"
                elif 'Dirty' == vals[locs.index(loc_D)]:
                    return random.choice(["Right", "Down"])
            if location == loc_B: 
                if 'Dirty' == vals[locs.index(loc_A)]:
                    return "Left"
                elif 'Dirty' == vals[locs.index(loc_D)]:
                    return "Down"
                elif 'Dirty' == vals[locs.index(loc_C)]:
                    return random.choice(["Left", "Down"])
            if location == loc_C: 
                if 'Dirty' == vals[locs.index(loc_A)]:
                    return "Up"
                elif 'Dirty' == vals[locs.index(loc_D)]:
                    return "Right"
                elif 'Dirty' == vals[locs.index(loc_B)]:
                    return random.choice(["Right", "Up"])
            if location == loc_D: 
                if 'Dirty' == vals[locs.index(loc_C)]:
                    return "Left"
                elif 'Dirty' == vals[locs.index(loc_B)]:
                    return "Up"
                elif 'Dirty' == vals[locs.index(loc_A)]:
                    return random.choice(["Left", "Up"])

        
    return Agent(program)

###################################################################################################
#                            INTERFACE METHODS TO CREATE AND MOVE THE AGENT
###################################################################################################

def create_agent(env, agent, MyImage):
    """Creates the agent in the GUI and is kept independent of the environment."""
    env.add_thing(agent)
    
    i = locs.index(agent.location)
    p = pos[i]

    x, y = p[0], p[1] - 50
    
    env.text = env.canvas.create_text(x, y, font="Helvetica 10 bold italic", text="Agent")
    env.agent_logo = env.canvas.create_image(x, y, image=MyImage)


def move_agent(env, agent, before_step):
    """Moves the agent in the GUI when 'next' button is pressed."""
    # Calculate the difference in location between the previous and current location
    if agent.location == before_step:
        # No movement if the location hasn't changed
        return
    
    # Get current and previous positions
    before_x, before_y = pos[locs.index(before_step)]
    current_x, current_y = pos[locs.index(agent.location)]

    # Calculate the movement in x and y directions
    move_x = current_x - before_x
    move_y = current_y - before_y

    # Move both the text and agent logo on the canvas
    env.canvas.move(env.text, move_x, move_y)
    env.canvas.move(env.agent_logo, move_x, move_y)

# TODO: Add more agents to the environment.
# TODO: Expand the environment to XYEnvironment.

###################################################################################################
#                                           MAIN LOOP
###################################################################################################
def main():
    """The main function of the program."""
    root = Tk()
    root.title("Vacuum Environment")
    root.geometry("500x500")
    root.resizable(0, 0)
    frame = Frame(root, bg='black')
    
    MyImage = PhotoImage(file="AgentVacuum.png")

    next_button = Button(frame, text='Next', height=2, width=6, padx=2, pady=2)
    next_button.pack(side='left')
    frame.pack(side='bottom')
    
    env = Gui(root)
    agent = ReflexVacuumAgent()
    create_agent(env, agent, MyImage)
    
    next_button.config(command=lambda: env.update_env(agent))
    
    root.mainloop()


if __name__ == "__main__":
    main()
# Out:
# {(0, 0): 'Clean', (1, 0): 'Dirty', (0, 1): 'Clean', (1, 1): 'Clean'}
# Perceived Location= (0, 0)  - Perceived StatusAtLoc= Clean
# Perceived Status:  ((0, 0), {(0, 0): 'Clean', (1, 0): 'Dirty', (0, 1): 'Clean', (1, 1): 'Clean'})
# Executing action:  Right
# Current Environment Status:  {(0, 0): 'Clean', (1, 0): 'Dirty', (0, 1): 'Clean', (1, 1): 'Clean'}
# Current Agent Location:  (1, 0)
# {(0, 0): 'Clean', (1, 0): 'Dirty', (0, 1): 'Clean', (1, 1): 'Clean'}
# Perceived Location= (1, 0)  - Perceived StatusAtLoc= Dirty
# Perceived Status:  ((1, 0), {(0, 0): 'Clean', (1, 0): 'Dirty', (0, 1): 'Clean', (1, 1): 'Clean'})
# Executing action:  Suck
# Current Environment Status:  {(0, 0): 'Clean', (1, 0): 'Clean', (0, 1): 'Clean', (1, 1): 'Clean'}
# Current Agent Location:  (1, 0)
# {(0, 0): 'Clean', (1, 0): 'Clean', (0, 1): 'Clean', (1, 1): 'Dirty'}
# Perceived Location= (1, 0)  - Perceived StatusAtLoc= Clean
# Perceived Status:  ((1, 0), {(0, 0): 'Clean', (1, 0): 'Clean', (0, 1): 'Clean', (1, 1): 'Dirty'})
# Executing action:  Down
# Current Environment Status:  {(0, 0): 'Clean', (1, 0): 'Clean', (0, 1): 'Clean', (1, 1): 'Dirty'}
# Current Agent Location:  (1, 1)
# {(0, 0): 'Clean', (1, 0): 'Clean', (0, 1): 'Clean', (1, 1): 'Dirty'}
# Perceived Location= (1, 1)  - Perceived StatusAtLoc= Dirty
# Perceived Status:  ((1, 1), {(0, 0): 'Clean', (1, 0): 'Clean', (0, 1): 'Clean', (1, 1): 'Dirty'})
# Executing action:  Suck
# Current Environment Status:  {(0, 0): 'Clean', (1, 0): 'Clean', (0, 1): 'Clean', (1, 1): 'Clean'}
# Current Agent Location:  (1, 1)
# {(0, 0): 'Clean', (1, 0): 'Clean', (0, 1): 'Dirty', (1, 1): 'Clean'}
# Perceived Location= (1, 1)  - Perceived StatusAtLoc= Clean
# Perceived Status:  ((1, 1), {(0, 0): 'Clean', (1, 0): 'Clean', (0, 1): 'Dirty', (1, 1): 'Clean'})
# Executing action:  Left
# Current Environment Status:  {(0, 0): 'Clean', (1, 0): 'Clean', (0, 1): 'Dirty', (1, 1): 'Clean'}
# Current Agent Location:  (0, 1)
# {(0, 0): 'Clean', (1, 0): 'Clean', (0, 1): 'Dirty', (1, 1): 'Clean'}
# Perceived Location= (0, 1)  - Perceived StatusAtLoc= Dirty
# Perceived Status:  ((0, 1), {(0, 0): 'Clean', (1, 0): 'Clean', (0, 1): 'Dirty', (1, 1): 'Clean'})
# Executing action:  Suck
# Current Environment Status:  {(0, 0): 'Clean', (1, 0): 'Clean', (0, 1): 'Clean', (1, 1): 'Clean'}
# Current Agent Location:  (0, 1)
# {(0, 0): 'Clean', (1, 0): 'Clean', (0, 1): 'Clean', (1, 1): 'Clean'}
# Perceived Location= (0, 1)  - Perceived StatusAtLoc= Clean
# Perceived Status:  ((0, 1), {(0, 0): 'Clean', (1, 0): 'Clean', (0, 1): 'Clean', (1, 1): 'Clean'})
# Executing action:  Right
# Current Environment Status:  {(0, 0): 'Clean', (1, 0): 'Clean', (0, 1): 'Clean', (1, 1): 'Clean'}
# Current Agent Location:  (1, 1)
# {(0, 0): 'Clean', (1, 0): 'Clean', (0, 1): 'Clean', (1, 1): 'Clean'}
# Perceived Location= (1, 1)  - Perceived StatusAtLoc= Clean
# Perceived Status:  ((1, 1), {(0, 0): 'Clean', (1, 0): 'Clean', (0, 1): 'Clean', (1, 1): 'Clean'})
# Executing action:  Up
# Current Environment Status:  {(0, 0): 'Clean', (1, 0): 'Clean', (0, 1): 'Clean', (1, 1): 'Clean'}
# Current Agent Location:  (1, 0)
# {(0, 0): 'Clean', (1, 0): 'Clean', (0, 1): 'Clean', (1, 1): 'Clean'}
# Perceived Location= (1, 0)  - Perceived StatusAtLoc= Clean
# Perceived Status:  ((1, 0), {(0, 0): 'Clean', (1, 0): 'Clean', (0, 1): 'Clean', (1, 1): 'Clean'})
# Executing action:  Left
# Current Environment Status:  {(0, 0): 'Clean', (1, 0): 'Clean', (0, 1): 'Clean', (1, 1): 'Clean'}
# Current Agent Location:  (0, 0)
# {(0, 0): 'Dirty', (1, 0): 'Clean', (0, 1): 'Clean', (1, 1): 'Clean'}
# Perceived Location= (0, 0)  - Perceived StatusAtLoc= Dirty
# Perceived Status:  ((0, 0), {(0, 0): 'Dirty', (1, 0): 'Clean', (0, 1): 'Clean', (1, 1): 'Clean'})
# Executing action:  Suck
# Current Environment Status:  {(0, 0): 'Clean', (1, 0): 'Clean', (0, 1): 'Clean', (1, 1): 'Clean'}
# Current Agent Location:  (0, 0)
